# %%
import pandas as pd #To hand with data 
import numpy as np #To math 
import seaborn as sns #to visualization
import matplotlib.pyplot as plt # to plot the graphs
import matplotlib.gridspec as gridspec # to do the grid of plots

# %matplotlib inline

# %%
data = pd.read_csv('trainbase.csv')
data.head(3)
# Out:
#             id  creditlimit  n_cards  os_balance  os_billing  \
# 0  20210100001    7000000.0        2       36158     23437.0
# 1  20210100002   10000000.0        2      268691    254564.0
# 2  20210100003   28000000.0        3     6769149   4159779.0
#
#    tot_cash_advance_trx  tot_retail_trx  remaining_unpaid_balance branchcode  \
# 0                   0.0            94.0                   26323.0          I
# 1                   0.0          1012.0                       0.0          A
# 2                   0.0             0.0                       0.0          A
#
#    rasio_pembayaranpayment_ratio  ...  good_bad_flag  loan_tenure  total_trx  \
# 0                         102.19  ...              0    15.416667       94.0
# 1                           0.00  ...              0     0.750000     1012.0
# 2                         100.00  ...              0    10.750000        0.0
#
#    remaining_statement_balance_per_n_cards  \
# 0                                  13161.5
# ...

# %%
pd.value_counts(data['good_bad_flag']).plot.bar()
plt.title('Fraud class histogram')
plt.xlabel('good_bad_flag')
plt.ylabel('Frequency')
data['good_bad_flag'].value_counts()
# Out:
# 0    12008
# 1     1162
# Name: good_bad_flag, dtype: int64

# %%
data[['creditlimit','n_cards','os_balance','os_billing','good_bad_flag']].describe()
# Out:
#         creditlimit       n_cards    os_balance    os_billing  good_bad_flag
# count  1.317000e+04  13170.000000  1.317000e+04  1.317000e+04   13170.000000
# mean   2.070004e+07      2.503493  1.160585e+07  8.115265e+06       0.088231
# std    2.957703e+07      1.012502  2.378763e+07  1.771476e+07       0.283641
# min    3.000000e+06      1.000000  0.000000e+00  2.004300e+04       0.000000
# 25%    5.000000e+06      2.000000  1.998926e+06  8.147260e+05       0.000000
# 50%    9.000000e+06      2.000000  4.705553e+06  3.154396e+06       0.000000
# 75%    2.200000e+07      3.000000  1.064840e+07  7.464537e+06       0.000000
# max    1.000000e+09     16.000000  7.980586e+08  6.280000e+08       1.000000

# %%
print("Distribuition of Normal(0) and Frauds(1): ")
print(data["good_bad_flag"].value_counts())

plt.figure(figsize=(7,5))
sns.countplot(data['good_bad_flag'])
plt.title("Class Count", fontsize=18)
plt.xlabel("Is fraud?", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.show()
# Out:
# Distribuition of Normal(0) and Frauds(1):
# 0    12008
# 1     1162
# Name: good_bad_flag, dtype: int64

# %%
data.hist(figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa45a7c4ca0>,
# ...
#       dtype=object)

# %%
data['creditlimit'].value_counts()
# Out:
# 3000000.0      1869
# 5000000.0      1787
# 7000000.0       941
# 10000000.0      826
# 20000000.0      810
#                ...
# 500000000.0       1
# 107000000.0       1
# 178000000.0       1
# 122000000.0       1
# 125000000.0       1
# Name: creditlimit, Length: 147, dtype: int64

# %%
data['os_balance'].value_counts()
# Out:
# 97638       7
# 132613      7
# 4594088     6
# 515000      6
# 1937295     5
#            ..
# 4185736     1
# 10655369    1
# 5109016     1
# 4828822     1
# 19773300    1
# Name: os_balance, Length: 9338, dtype: int64

# %%
plt.figure(figsize=(20,20))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(data.corr(), annot=True,cmap ='RdYlGn')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13170 entries, 0 to 13169
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       13170 non-null  int64
#  1   creditlimit                              13170 non-null  float64
#  2   n_cards                                  13170 non-null  int64
#  3   os_balance                               13170 non-null  int64
#  4   os_billing                               13170 non-null  float64
#  5   tot_cash_advance_trx                     13170 non-null  float64
#  6   tot_retail_trx                           13170 non-null  float64
#  7   remaining_unpaid_balance                 13170 non-null  float64
#  8   branchcode                               13084 non-null  object
#  9   rasio_pembayaranpayment_ratio            13170 non-null  float64
# ...

# %%
fig, (ax1, ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11) = plt.subplots(1,11, figsize=(33,3))

sns.scatterplot(x='creditlimit',y='n_cards', data=data, hue='good_bad_flag',ax=ax1)
sns.scatterplot(x='os_balance',y='os_billing', data=data, hue='good_bad_flag',ax=ax2)

sns.scatterplot(x='tot_cash_advance_trx',y='tot_retail_trx', data=data, hue='good_bad_flag',ax=ax3)
sns.scatterplot(x='remaining_unpaid_balance',y='remaining_unpaid_balance', data=data, hue='good_bad_flag',ax=ax4)

sns.scatterplot(x='rasio_pembayaranpayment_ratio',y='overlimit_pct', data=data, hue='good_bad_flag',ax=ax5)
sns.scatterplot(x='payment_ration_3months',y='payment_ration_6months', data=data, hue='good_bad_flag',ax=ax6)

sns.scatterplot(x='deliquncy_score',y='loan_tenure', data=data, hue='good_bad_flag',ax=ax7)
sns.scatterplot(x='total_trx',y='total_trx_per_limit', data=data, hue='good_bad_flag',ax=ax8)

sns.scatterplot(x='remaining_statement_balance_per_n_cards',y='remaining_statement_balance_per_limit', data=data, hue='good_bad_flag',ax=ax9)
sns.scatterplot(x='tot_trx_3months_per_limit',y='tot_trx_6months_per_limit', data=data, hue='good_bad_flag',ax=ax10)
sns.scatterplot(x='utilization_Rate_3months',y='utilization_Rate_6months', data=data, hue='good_bad_flag',ax=ax11)

# %%
from imblearn.pipeline import make_pipeline as make_pipeline_imb # To do our transformation in a unique time
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import make_pipeline
from imblearn.metrics import classification_report_imbalanced

from sklearn.model_selection import train_test_split
from collections import Counter

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import precision_score, recall_score, fbeta_score, confusion_matrix, precision_recall_curve, accuracy_score

# %%
X = data.drop(["good_bad_flag"], axis=1).values #Setting the X to do the split
y = data["good_bad_flag"].values # transforming the values in array

# %%
# the function that we will use to better evaluate the model
def print_results(headline, true_value, pred):
    print(headline)
    print("accuracy: {}".format(accuracy_score(true_value, pred)))
    print("precision: {}".format(precision_score(true_value, pred)))
    print("recall: {}".format(recall_score(true_value, pred)))
    print("f2: {}".format(fbeta_score(true_value, pred, beta=2)))

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2, test_size=0.20)

# %%
classifier = RandomForestClassifier

# %%
smote_pipeline = make_pipeline_imb(SMOTE(random_state=4), \
                                   classifier(random_state=42))
